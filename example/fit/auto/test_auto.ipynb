# %% [markdown]
# # Auto Fit

# %%
import numpy as np
from smpl import plot
from smpl import stat
from smpl import functions as f
import uncertainties.unumpy as unp
import smpl

# %%
for n in ['test_linear_data.txt', 'test_quad_data.txt']:
    data = np.loadtxt(n)
    xdata = data[:,0]
    xerr = data[:,2]
    ydata = data[:,1]
    yerr = data[:,3]
    x = unp.uarray(xdata,xerr)
    y = unp.uarray(ydata,yerr)


    function,fitparams,lfunc = plot.auto(xdata, ydata, fmt='.', label='data', xaxis="x in a.u.",yaxis="y in a.u.",sigmas=1,epsfcn=0.00001,maxfev=1000000,init=True)
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]
#  48%|████▊     | 12/25 [00:00<00:00, 13.33it/s]
#  64%|██████▍   | 16/25 [00:02<00:01,  6.55it/s]
#  68%|██████▊   | 17/25 [00:02<00:01,  4.70it/s]
# 100%|██████████| 25/25 [00:02<00:00,  8.36it/s]
#   0%|          | 0/25 [00:00<?, ?it/s]
#  48%|████▊     | 12/25 [00:00<00:00, 13.52it/s]
#  64%|██████▍   | 16/25 [00:02<00:01,  6.86it/s]
# 100%|██████████| 25/25 [00:02<00:00, 11.82it/s]

# %%
x= np.linspace(-5,5,100)
y = stat.noisy(np.exp(2*x))
ff = plot.auto(x, y, fmt='.', label='data', xaxis="x in a.u.",yaxis="y in a.u.",sigmas=1)
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]
# /opt/hostedtoolcache/Python/3.7.12/x64/lib/python3.7/site-packages/uncertainties/core.py:171: RuntimeWarning: invalid value encountered in sqrt
#   std_devs = numpy.sqrt(numpy.diag(covariance_mat))
#  64%|██████▍   | 16/25 [00:03<00:01,  5.24it/s]
#  76%|███████▌  | 19/25 [00:03<00:00,  6.22it/s]
# 100%|██████████| 25/25 [00:03<00:00,  7.63it/s]
