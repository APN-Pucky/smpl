# %% [markdown]
# # Residue Plot

# %%
from smpl import plot
from smpl import functions as f
import numpy as np
import uncertainties.unumpy as unp
import matplotlib.pyplot as plt
# Out:
# You are using an unreleased version.

# %%
dat = np.loadtxt("dat.dat", skiprows=0, delimiter=" ")


xdata = dat[:,0]
ydata = dat[:,1]
ymodel = dat[:,-2]

# %%
plot.data(xdata,ydata,logy=True,ss=False)
plot.data(xdata,ymodel,fmt="-",logy=True,init=False,label="model")

# %%
data = np.loadtxt('test_linear_data.txt')
xdata = data[:,0]
xerr = data[:,2]
ydata = data[:,1]
yerr = data[:,3]
x = unp.uarray(xdata,xerr)
y = unp.uarray(ydata,yerr)

# %%
plot.fit(x,y,function=f.line,residue=True,xaxis="t",yaxis="s",units=["l","b"],sigmas=1)
# Out:
# /usr/lib/python3/dist-packages/matplotlib/figure.py:2022: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "
# array([1.0034626572607985+/-0.0594757806970322,
#        1.0370200979931061+/-0.1983801681636519], dtype=object)

# %%
plot.fit(x,y,function=f.line,residue=True,xaxis="t",yaxis="s",units=["l","b"],sigmas=1,residue_err=False)
# Out:
# /usr/lib/python3/dist-packages/matplotlib/figure.py:2022: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "
# array([1.0034626572607985+/-0.0594757806970322,
#        1.0370200979931061+/-0.1983801681636519], dtype=object)
