# %%
import numpy as np
from smpl import plot
from smpl import functions as f
import uncertainties.unumpy as unp

# %%
data = np.loadtxt('test_linear_data.txt')
xdata = data[:,0]
xerr = data[:,2]
ydata = data[:,1]
yerr = data[:,3]
x = unp.uarray(xdata,xerr)
y = unp.uarray(ydata,yerr)

# %%
data
# Out:
# array([[0. , 1. , 0.1, 0.2],
#        [1. , 2. , 0.2, 0.1],
#        [2. , 3. , 0.3, 0.1],
#        [3. , 5. , 0.1, 0.4],
#        [4. , 5. , 0.1, 0.1],
#        [5. , 6. , 0.1, 0.2]])

# %%
ff = plot.fit(xdata, ydata, fmt='.', function=f.Gerade, params=[1,2], sigmas=1,lpos=2)

# %%
ff = plot.fit(xdata, y, fmt='.', function=f.Gerade, params=[1,2], sigmas=1,lpos=2)

# %%
ff = plot.fit(x, y, fmt='.', function=f.Gerade, params=[1,1], sigmas=1,lpos=2)
