# %% [markdown]
# # Auto Fit

# %%
import numpy as np
from smpl import plot
from smpl import stat
from smpl import io
from smpl import functions as f
import uncertainties.unumpy as unp
import smpl

# %%
for n in ['test_linear_data.txt', 'test_quad_data.txt']:
    data = np.loadtxt(io.find_file(n,3))
    xdata = data[:,0]
    xerr = data[:,2]
    ydata = data[:,1]
    yerr = data[:,3]
    x = unp.uarray(xdata,xerr)
    y = unp.uarray(ydata,yerr)


    function,fitparams,lfunc = plot.auto(xdata, ydata, fmt='.', label='data', xaxis="x in a.u.",yaxis="y in a.u.",sigmas=1,epsfcn=0.00001,maxfev=1000000,init=True)
# Out:
# function: None
#   0%|          | 0/26 [00:00<?, ?it/s]
#  46%|████▌     | 12/26 [00:00<00:00, 21.22it/s]
#  62%|██████▏   | 16/26 [00:01<00:00, 10.39it/s]
#  69%|██████▉   | 18/26 [00:01<00:00,  8.32it/s]
# 100%|██████████| 26/26 [00:01<00:00, 13.88it/s]
# function: None
#   0%|          | 0/26 [00:00<?, ?it/s]
#  46%|████▌     | 12/26 [00:00<00:00, 21.42it/s]
#  62%|██████▏   | 16/26 [00:01<00:00, 10.83it/s]
# 100%|██████████| 26/26 [00:01<00:00, 19.38it/s]

# %%
x= np.linspace(-5,5,100)
y = stat.noisy(np.exp(2*x))
ff = plot.auto(x, y, fmt='.', label='data', xaxis="x in a.u.",yaxis="y in a.u.",sigmas=1)
# Out:
# function: None
#   0%|          | 0/26 [00:00<?, ?it/s]
#  62%|██████▏   | 16/26 [00:01<00:01,  8.37it/s]
# 100%|██████████| 26/26 [00:02<00:00, 12.98it/s]
