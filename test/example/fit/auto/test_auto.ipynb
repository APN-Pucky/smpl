# %% [markdown]
# # Auto Fit

# %%
import numpy as np
from smpl import plot
from smpl import stat
from smpl import io
from smpl import functions as f
import uncertainties.unumpy as unp
import smpl

# %%
for n in ['test_linear_data.txt', 'test_quad_data.txt']:
    data = np.loadtxt(io.find_file(n,3))
    xdata = data[:,0]
    xerr = data[:,2]
    ydata = data[:,1]
    yerr = data[:,3]
    x = unp.uarray(xdata,xerr)
    y = unp.uarray(ydata,yerr)


    function,fitparams,lfunc = plot.auto(xdata, ydata, fmt='.', label='data', xaxis="x in a.u.",yaxis="y in a.u.",sigmas=1,epsfcn=0.00001,maxfev=1000000,init=True)
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]
#  48%|████▊     | 12/25 [00:00<00:00, 20.25it/s]
#  64%|██████▍   | 16/25 [00:01<00:00,  9.95it/s]
#  72%|███████▏  | 18/25 [00:01<00:00,  7.91it/s]
# 100%|██████████| 25/25 [00:01<00:00, 12.72it/s]
#   0%|          | 0/25 [00:00<?, ?it/s]
#  48%|████▊     | 12/25 [00:00<00:00, 20.64it/s]
#  64%|██████▍   | 16/25 [00:01<00:00, 10.50it/s]
# 100%|██████████| 25/25 [00:01<00:00, 18.07it/s]

# %%
x= np.linspace(-5,5,100)
y = stat.noisy(np.exp(2*x))
ff = plot.auto(x, y, fmt='.', label='data', xaxis="x in a.u.",yaxis="y in a.u.",sigmas=1)
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]
# /usr/local/lib/python3.8/dist-packages/uncertainties/core.py:171: RuntimeWarning: invalid value encountered in sqrt
#   std_devs = numpy.sqrt(numpy.diag(covariance_mat))
#  64%|██████▍   | 16/25 [00:01<00:01,  8.26it/s]
#  92%|█████████▏| 23/25 [00:02<00:00, 12.47it/s]
# 100%|██████████| 25/25 [00:02<00:00, 12.15it/s]
