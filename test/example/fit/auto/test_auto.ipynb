# %% [markdown]
# # Automatic fit function

# %%
import numpy as np
from smpl import plot
from smpl import stat
from smpl import io
from smpl import functions as f
import uncertainties.unumpy as unp
import smpl
smpl.__version__
# Out:
# '1.0.1.6'

# %%
for n in ['test_linear_data.txt', 'test_quad_data.txt']:
    data = np.loadtxt(io.find_file(n,3))
    xdata = data[:,0]
    xerr = data[:,2]
    ydata = data[:,1]
    yerr = data[:,3]
    x = unp.uarray(xdata,xerr)
    y = unp.uarray(ydata,yerr)


    function,fitparams,lfunc = plot.auto(xdata, ydata, fmt='.', label='data', xaxis="x in a.u.",yaxis="y in a.u.",sigmas=1,epsfcn=0.00001,maxfev=1000000,init=True)
# Out:
# function: None
#   0%|          | 0/26 [00:00<?, ?it/s]
#  65%|██████▌   | 17/26 [00:00<00:00, 24.36it/s]
#  81%|████████  | 21/26 [00:01<00:00, 16.98it/s]
#  92%|█████████▏| 24/26 [00:01<00:00, 14.11it/s]
# 100%|██████████| 26/26 [00:01<00:00, 17.32it/s]
# function: None
#   0%|          | 0/26 [00:00<?, ?it/s]
#  65%|██████▌   | 17/26 [00:00<00:00, 27.23it/s]
#  81%|████████  | 21/26 [00:01<00:00, 17.89it/s]
# 100%|██████████| 26/26 [00:01<00:00, 23.93it/s]

# %%
x= np.linspace(-5,5,100)
y = stat.noisy(np.exp(2*x))
ff = plot.auto(x, y, fmt='.', label='data', xaxis="x in a.u.",yaxis="y in a.u.",sigmas=1)
# Out:
# function: None
#   0%|          | 0/26 [00:00<?, ?it/s]
#  65%|██████▌   | 17/26 [00:00<00:00, 133.88it/s]
# 100%|██████████| 26/26 [00:00<00:00, 33.43it/s]
