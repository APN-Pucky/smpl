# %% [markdown]
# # Auto Fit

# %%
import numpy as np
from smpl import plot
from smpl import functions as f
import uncertainties.unumpy as unp

# %%
data = np.loadtxt('test_linear_data.txt')
xdata = data[:,0]
xerr = data[:,2]
ydata = data[:,1]
yerr = data[:,3]
x = unp.uarray(xdata,xerr)
y = unp.uarray(ydata,yerr)

# %%
data
# Out:
# array([[-3.0e+00, -2.0e+00,  1.0e-02,  1.0e-02],
#        [-2.0e+00, -1.0e+00,  3.0e-01,  5.0e-01],
#        [-1.0e+00,  0.0e+00,  1.0e-01,  1.0e-01],
#        [ 0.0e+00,  1.0e+00,  1.0e-01,  2.0e-01],
#        [ 1.0e+00,  2.0e+00,  2.0e-01,  1.0e-01],
#        [ 2.0e+00,  3.0e+00,  3.0e-01,  1.0e-01],
#        [ 3.0e+00,  5.0e+00,  1.0e-01,  4.0e-01],
#        [ 4.0e+00,  5.0e+00,  1.0e-01,  1.0e-01],
#        [ 5.0e+00,  6.0e+00,  1.0e-01,  2.0e-01],
#        [ 6.0e+00,  7.0e+00,  1.0e-01,  2.0e-01],
#        [ 7.5e+00,  8.0e+00,  1.0e-01,  2.0e-01],
#        [ 8.0e+00,  8.8e+00,  1.0e-01,  2.0e-01],
#        [ 9.0e+00,  1.0e+01,  1.0e-01,  1.0e-01],
#        [ 1.0e+01,  1.1e+01,  1.0e-02,  1.0e-02]])

# %%
ff = plot.auto(xdata, ydata, fmt='.', label='data', xaxis="x in a.u.",yaxis="y in a.u.")
# Out:
# __name__
# __doc__
# __package__
# __loader__
# __spec__
# __path__
# __file__
# __cached__
# __builtins__
# functions
# const
# lorentz
# linear
# line
# cos_abs
# gauss
# quadratic
# exponential
# __all__

# %%
ff = plot.fit(xdata, ydata, fmt='.', label='data', xaxis="x in a.u.",yaxis="y in a.u.",function=f.line, params=[1,2])

# %%
ff = plot.fit(xdata, y, fmt='.', function=f.line, params=[1,1], sigmas=1,lpos=2)

# %%
ff = plot.fit(x, y, fmt='.', function=f.line, params=[1,1], sigmas=1,lpos=2)
