# %%
import numpy as np
from smpl import plot

# %%
def gompertz(n,a,b):
    return -a * n * np.log(b*n)

def solution_gompertz(t,a,b,c):
    return 1/b*np.exp(np.exp(-t*a)*c)

# %% [markdown]
# # Multi Plot
# ## Different color
#
#
# Separation of Variables:
#
# $$\int \frac{1}{N \ln (bN)} dN = \ln(\ln(bN)) +c= -adt =-at$$
#
# $$\implies N(t) =  \frac{1}{b} \exp (c \exp (-t a))$$

# %%
for a in [1,2]:
    for b in [1,0.5]:
        plot.function( gompertz, a,b, xaxis="$N$", yaxis="$\\dot N$",xmin=0.1, xmax=3 ,init=False )

# %%
for a in [1,2]:
    for b in [1,1/8]:
        for c in [1,2]:
            plot.function( solution_gompertz, a,b,c, xaxis="$t$", yaxis="$N$",xmin=0.1, xmax=3,init=False,label="")
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# ## Same color

# %%
for a in [1,2]:
    for b in [1,1/8]:
        for c in [1,2]:
            plot.function( solution_gompertz, a,b,c, xaxis="$t$", yaxis="$N$",xmin=0.1, xmax=3,init=False,label="",next_color=False)
# Out:
# <itertools.cycle object at 0x7f6fb25bf100>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_25023/187579230.py in <module>
#       2     for b in [1,1/8]:
#       3         for c in [1,2]:
# ----> 4             plot.function( solution_gompertz, a,b,c, xaxis="$t$", yaxis="$N$",xmin=0.1, xmax=3,init=False,label="",next_color=False)
#
# ~/.local/lib/python3.9/site-packages/smpl/plot/plot.py in function(func, *args, **kwargs)
#     255     kwargs = plot_kwargs(kwargs)
#     256     xlin = np.linspace(kwargs['xmin'], kwargs['xmax'], kwargs['steps'])
# --> 257     init_plot(**kwargs)
#     258
#     259     if not util.has("label", kwargs) or kwargs['label'] is None:
#
# ~/.local/lib/python3.9/site-packages/smpl/plot/plot.py in init_plot(**kwargs)
#     410     if util.has("next_color",kwargs) and not kwargs['next_color']:
#     411         print(plt.gca()._get_lines.prop_cycler)
# --> 412         tmp_color = next(cycler(plt.gca()._get_lines.prop_cycler))['color']
#     413         if kwargs['data_color'] is None:
#     414             kwargs['data_color'] = tmp_color
#
# ~/.local/lib/python3.9/site-packages/cycler.py in cycler(*args, **kwargs)
#     512     if len(args) == 1:
#     513         if not isinstance(args[0], Cycler):
# --> 514             raise TypeError("If only one positional argument given, it must "
#     515                             " be a Cycler instance.")
#     516         return Cycler(args[0])
#
# TypeError: If only one positional argument given, it must  be a Cycler instance.
