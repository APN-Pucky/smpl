# %% [markdown]
# # Plot2d
#
# Plot2d takes 3 1-dim arrays (x, y and z), where each index is one point.

# %%
from smpl import plot
import numpy as np

# %%
xvalues = np.linspace(-10,10,20)
yvalues = np.linspace(-10,10,20)
xx, yy = np.meshgrid(xvalues, yvalues)
xx = xx.reshape(xx.size)
yy = yy.reshape(yy.size)
plot.plot2d(xx,yy,xx**2+yy**2+10*xx+10*yy,fill_missing=False,interpolation="bilinear",logz=False)

# %%
xvalues = np.linspace(-10,10,20)
yvalues = xvalues*2
xx = xvalues
yy = yvalues
xx = np.append(xx,xx)
yy = np.append(yy,-yy)
zz = xx**2+yy**2
plot.plot2d(xx,yy,xx**2+yy**2,fill_missing=True)
plot.plot2d(xx,yy,xx**2+yy**2,style='scatter',fill_missing=True)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /tmp/ipykernel_15229/993538585.py in <module>
#       6 yy = np.append(yy,-yy)
#       7 zz = xx**2+yy**2
# ----> 8 plot.plot2d(xx,yy,xx**2+yy**2,fill_missing=True)
#       9 plot.plot2d(xx,yy,xx**2+yy**2,style='scatter',fill_missing=True)
#
# ~/.local/lib/python3.8/site-packages/smpl/plot/plot2d.py in plot2d(datax, datay, dataz, **kwargs)
#      44     kwargs = plot2d_kwargs(kwargs)
#      45     if kwargs["style"] =="image":
# ---> 46         map_vplot(datax,datay,dataz,**kwargs)
#      47     elif (kwargs["style"] =="scatter"):
#      48         scatter_vplot(datax,datay,dataz,**kwargs)
#
# ~/.local/lib/python3.8/site-packages/smpl/plot/plot2d.py in map_vplot(tvx, tvy, tvz, xaxis, yaxis, zaxis, logz, sort, fill_missing, zscale, **kwargs)
#     102     yl = vy.min() + (vy.min() / 2) - vy[vy != vy.min()].min() / 2
#     103     ym = vy.max() + (vy.max() / 2) - vy[vy != vy.max()].max() / 2
# --> 104     im = NonUniformImage(
#     105         ax,
#     106         origin="lower",
#
# ~/.local/lib/python3.8/site-packages/matplotlib/image.py in __init__(self, ax, interpolation, **kwargs)
#    1022         """
#    1023         super().__init__(ax, **kwargs)
# -> 1024         self.set_interpolation(interpolation)
#    1025
#    1026     def _check_unsampled_image(self):
#
# ~/.local/lib/python3.8/site-packages/matplotlib/image.py in set_interpolation(self, s)
#    1109         """
#    1110         if s is not None and s not in ('nearest', 'bilinear'):
# -> 1111             raise NotImplementedError('Only nearest neighbor and '
#    1112                                       'bilinear interpolations are supported')
#    1113         super().set_interpolation(s)
#
# NotImplementedError: Only nearest neighbor and bilinear interpolations are supported
