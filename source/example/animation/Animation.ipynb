# %%
import smpl
from smpl import animation
from smpl import plot
from smpl import io
import numpy as np
import matplotlib.pyplot as plt
import tqdm

# %%
# %matplotlib notebook 
plt.ioff()
for a in tqdm.tqdm(np.linspace(0,10,200)):
    plot.function(lambda x : a*x**2,xmin=0,xmax=5,init=True,tight=False)
    animation.frame()

#ani.save("test.gif")
ani = animation.animate(interval=10)
plt.show()
# Out:
# 100%|██████████| 200/200 [00:05<00:00, 38.41it/s]
# <img src="data:image/png;base64,..." width="767.5">

# %%
ani.save("test.gif")
